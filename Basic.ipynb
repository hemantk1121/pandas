# %% [markdown]
# <a href="https://colab.research.google.com/github/hemantk1121/pandas/blob/main/Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = [100,102,234]
series=pd.Series(data,index=["a","b","c"])
series.loc["c"]=500
series.iloc[1]=400
print(series[series>=200])
# Out:
# b    400
# c    500
# dtype: int64

# %%
import pandas as pd
data=["bulbasar","hemant","shagun"]
series=pd.Series(data)
print(series)
# Out:
# 0    bulbasar
# 1      hemant
# 2      shagun
# dtype: object

# %%
import pandas as pd
data={"Name":["udit","shagun","tushar"],
      "Age":[21,21,28],
}
df=pd.DataFrame(data,index=["employe 1","employe 2","employe 3"])
#new colume
df["job"]=["photographer","web devloper","gov.employe"]
new_rows=pd.DataFrame([
    {"Name":"sandy","Age":22,"job":"servent"},
    {"Name":"andy","Age":22,"job":"labour"}],index=["employe 4","employe 5"]
)
df=pd.concat([df,new_rows])


print(df)
# Out:
#              Name  Age           job
# employe 1    udit   21  photographer
# employe 2  shagun   21  web devloper
# employe 3  tushar   28   gov.employe
# employe 4   sandy   22       servent
# employe 5    andy   22        labour

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-02e7943a-db76-491e-a939-3290cc8e6d4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02e7943a-db76-491e-a939-3290cc8e6d4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data=pd.read_csv("Titanic-Dataset.csv")
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(data["Sex"])
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
print(data["Ticket"])
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
print(data["Cabin"])
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
print(data[['Name','Sex','Cabin']])
# Out:
#                                                   Name     Sex Cabin
# 0                              Braund, Mr. Owen Harris    male   NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   C85
# 2                               Heikkinen, Miss. Laina  female   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  C123
# 4                             Allen, Mr. William Henry    male   NaN
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male   NaN
# 887                       Graham, Miss. Margaret Edith  female   B42
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  C148
# 890                                Dooley, Mr. Patrick    male   NaN
#
# [891 rows x 3 columns]

# %%
import pandas as pd
data=pd.read_csv("Titanic-Dataset.csv",index_col="Name")
print(data)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
print(data.iloc[1:11:2,1:3])
# Out:
#                                                     Survived  Pclass
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1
# Moran, Mr. James                                           0       3
# Palsson, Master. Gosta Leonard                             0       3
# Nasser, Mrs. Nicholas (Adele Achem)                        1       2

# %%
pokemon=input("enter the name:")
try:
  print(data.loc[pokemon])
except KeyError:
  print(f"{pokemon} not found")
# Out:
# enter the name:harsh
# harsh not found

# %%
gen=data[(data['Sex']=="male") &
          (data['Age']>20)]
print(gen)
# Out:
#                                PassengerId  Survived  Pclass   Sex   Age  \
# Name
# Braund, Mr. Owen Harris                  1         0       3  male  22.0
# Allen, Mr. William Henry                 5         0       3  male  35.0
# McCarthy, Mr. Timothy J                  7         0       1  male  54.0
# Andersson, Mr. Anders Johan             14         0       3  male  39.0
# Fynney, Mr. Joseph J                    21         0       2  male  35.0
# ...                                    ...       ...     ...   ...   ...
# Banfield, Mr. Frederick James          884         0       2  male  28.0
# Sutehall, Mr. Henry Jr                 885         0       3  male  25.0
# Montvila, Rev. Juozas                  887         0       2  male  27.0
# Behr, Mr. Karl Howell                  890         1       1  male  26.0
# Dooley, Mr. Patrick                    891         0       3  male  32.0
#
#                                SibSp  Parch            Ticket     Fare Cabin  \
# ...

# %%
print(data.mean(numeric_only=True))
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
print(data.sum(numeric_only=True))
# Out:
# PassengerId    397386.0000
# Survived          342.0000
# Pclass           2057.0000
# Age             21205.1700
# SibSp             466.0000
# Parch             340.0000
# Fare            28693.9493
# dtype: float64

# %%
print(data.min(numeric_only=True))
# Out:
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# dtype: float64

# %%
group=data.groupby('Sex')
print(group.mean(numeric_only=True))
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
group=data.groupby('Sex')
print(group['Ticket'].count())
# Out:
# Sex
# female    314
# male      577
# Name: Ticket, dtype: int64

# %%
group=data.groupby('Sex')
print(group['Age'].mean())
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
data.loc[data["Survived"]==0]
# Out:
#                                           PassengerId  Survived  Pclass  \
# Name
# Braund, Mr. Owen Harris                             1         0       3
# Allen, Mr. William Henry                            5         0       3
# Moran, Mr. James                                    6         0       3
# McCarthy, Mr. Timothy J                             7         0       1
# Palsson, Master. Gosta Leonard                      8         0       3
# ...                                               ...       ...     ...
# Sutehall, Mr. Henry Jr                            885         0       3
# Rice, Mrs. William (Margaret Norton)              886         0       3
# Montvila, Rev. Juozas                             887         0       2
# Johnston, Miss. Catherine Helen "Carrie"          889         0       3
# Dooley, Mr. Patrick                               891         0       3
#
#                                              Sex   Age  SibSp  Parch  \
# Name
# ...

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data[data["Pclass"]==1]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# McCarthy, Mr. Timothy J                                       7         0
# Bonnell, Miss. Elizabeth                                     12         1
# Sloper, Mr. William Thompson                                 24         1
# ...                                                         ...       ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)            872         1
# Carlsson, Mr. Frans Olof                                    873         0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
# Graham, Miss. Margaret Edith                                888         1
# Behr, Mr. Karl Howell                                       890         1
#
# ...

# %%
data.loc[data["Pclass"]==1].reset_index()[["Name","Age","Sex"]]
# Out:
#                                                   Name   Age     Sex
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 2                              McCarthy, Mr. Timothy J  54.0    male
# 3                             Bonnell, Miss. Elizabeth  58.0  female
# 4                         Sloper, Mr. William Thompson  28.0    male
# ..                                                 ...   ...     ...
# 211   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0  female
# 212                           Carlsson, Mr. Frans Olof  33.0    male
# 213      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0  female
# 214                       Graham, Miss. Margaret Edith  19.0  female
# 215                              Behr, Mr. Karl Howell  26.0    male
#
# [216 rows x 3 columns]

# %%
data.loc[data["Survived"]!=0].value_counts()
# Out:
# PassengerId  Survived  Pclass  Sex     Age   SibSp  Parch  Ticket    Fare     Cabin  Embarked
# 2            1         1       female  38.0  1      0      PC 17599  71.2833  C85    C           1
# 4            1         1       female  35.0  1      0      113803    53.1000  C123   S           1
# 11           1         3       female  4.0   1      1      PP 9549   16.7000  G6     S           1
# 12           1         1       female  58.0  0      0      113783    26.5500  C103   S           1
# 22           1         2       male    34.0  0      0      248698    13.0000  D56    S           1
#                                                                                                 ..
# 863          1         1       female  48.0  0      0      17466     25.9292  D17    S           1
# 872          1         1       female  47.0  1      1      11751     52.5542  D35    S           1
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.iloc[10:21]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Sandstrom, Miss. Marguerite Rut                              11         1
# Bonnell, Miss. Elizabeth                                     12         1
# Saundercock, Mr. William Henry                               13         0
# Andersson, Mr. Anders Johan                                  14         0
# Vestrom, Miss. Hulda Amanda Adolfina                         15         0
# Hewlett, Mrs. (Mary D Kingcome)                              16         1
# Rice, Master. Eugene                                         17         0
# Williams, Mr. Charles Eugene                                 18         1
# Vander Planke, Mrs. Julius (Emelia Maria Vandem...           19         0
# Masselmani, Mrs. Fatima                                      20         1
# Fynney, Mr. Joseph J                                         21         0
#
# ...

# %%
data[(data["Age"]>30) & (data["Sex"]=="male") & (data["Pclass"]==1)]
# Out:
#                                       PassengerId  Survived  Pclass   Sex  \
# Name
# McCarthy, Mr. Timothy J                         7         0       1  male
# Uruchurtu, Don. Manuel E                       31         0       1  male
# Holverson, Mr. Alexander Oskar                 36         0       1  male
# Ostby, Mr. Engelhart Cornelius                 55         0       1  male
# Harris, Mr. Henry Birkhardt                    63         0       1  male
# ...                                           ...       ...     ...   ...
# Andrews, Mr. Thomas Jr                        807         0       1  male
# Reuchlin, Jonkheer. John George               823         0       1  male
# Daly, Mr. Peter Denis                         858         1       1  male
# Roebling, Mr. Washington Augustus II          868         0       1  male
# Carlsson, Mr. Frans Olof                      873         0       1  male
#
# ...

# %%
data[(data["Age"]>30) & (data["Sex"]=="male") & (data["Pclass"]==1)].sum(numeric_only=True)
# Out:
# PassengerId    35134.0000
# Survived          27.0000
# Pclass            75.0000
# Age             3582.5000
# SibSp             26.0000
# Parch             19.0000
# Fare            4829.1085
# dtype: float64

# %%
data[data["Pclass"].isin([1,2])].sum(numeric_only=True)
# Out:
# PassengerId    181761.0000
# Survived          223.0000
# Pclass            584.0000
# Age             12280.2500
# SibSp             164.0000
# Parch             147.0000
# Fare            21979.2542
# dtype: float64

# %%
data[data["Pclass"].isin([1,2])]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# McCarthy, Mr. Timothy J                                       7         0
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# Bonnell, Miss. Elizabeth                                     12         1
# ...                                                         ...       ...
# Shelley, Mrs. William (Imanita Parrish Hall)                881         1
# Banfield, Mr. Frederick James                               884         0
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Behr, Mr. Karl Howell                                       890         1
#
# ...

# %%
data[(data["Age"]>30) | (data["Fare"]>100)]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# McCarthy, Mr. Timothy J                                       7         0
# Bonnell, Miss. Elizabeth                                     12         1
# ...                                                         ...       ...
# Vander Cruyssen, Mr. Victor                                 874         0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
# Markun, Mr. Johann                                          882         0
# Rice, Mrs. William (Margaret Norton)                        886         0
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
data[(data["Sex"]=="female") & (data["Survived"]==1)]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# ...                                                         ...       ...
# Abelson, Mrs. Samuel (Hannah Wizosky)                       875         1
# Najib, Miss. Adele Kiamie "Jane"                            876         1
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
# Shelley, Mrs. William (Imanita Parrish Hall)                881         1
# Graham, Miss. Margaret Edith                                888         1
#
# ...

# %%
data[(data["Sex"]=="male") & (data["Survived"]==0)]
# Out:
#                                 PassengerId  Survived  Pclass   Sex   Age  \
# Name
# Braund, Mr. Owen Harris                   1         0       3  male  22.0
# Allen, Mr. William Henry                  5         0       3  male  35.0
# Moran, Mr. James                          6         0       3  male   NaN
# McCarthy, Mr. Timothy J                   7         0       1  male  54.0
# Palsson, Master. Gosta Leonard            8         0       3  male   2.0
# ...                                     ...       ...     ...   ...   ...
# Markun, Mr. Johann                      882         0       3  male  33.0
# Banfield, Mr. Frederick James           884         0       2  male  28.0
# Sutehall, Mr. Henry Jr                  885         0       3  male  25.0
# Montvila, Rev. Juozas                   887         0       2  male  27.0
# Dooley, Mr. Patrick                     891         0       3  male  32.0
#
# ...

# %%
data.query('Age > 30')
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# McCarthy, Mr. Timothy J                                       7         0
# Bonnell, Miss. Elizabeth                                     12         1
# ...                                                         ...       ...
# Vander Cruyssen, Mr. Victor                                 874         0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
# Markun, Mr. Johann                                          882         0
# Rice, Mrs. William (Margaret Norton)                        886         0
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
del data['PassengerId']

# %%
data.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
#
# ...

# %%
data.drop(["Cabin","Ticket"], axis=1,inplace=True)

# %%
data.rename(columns={"Fare":"TIcket_fare"},inplace=True)

# %%
data.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
#
# ...

# %%
data.rename(columns={"PassengerId":"pass",
                     "Survived":"Jinda"},inplace=True)

# %%
data.head()
# Out:
#                                                     pass  Jinda  Pclass  \
# Name
# Braund, Mr. Owen Harris                                1      0       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...     2      1       1
# Heikkinen, Miss. Laina                                 3      1       3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           4      1       1
# Allen, Mr. William Henry                               5      0       3
#
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                               male  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
# Heikkinen, Miss. Laina                              female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35.0      1
# Allen, Mr. William Henry                              male  35.0      0
#
#                                                     Parch            Ticket  \
# Name
# ...

# %%
data["FamilySize"]=data["SibSp"]+data["Parch"]+1

# %%
data.head()
# Out:
#                                                     pass  Jinda  Pclass  \
# Name
# Braund, Mr. Owen Harris                                1      0       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...     2      1       1
# Heikkinen, Miss. Laina                                 3      1       3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           4      1       1
# Allen, Mr. William Henry                               5      0       3
#
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                               male  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
# Heikkinen, Miss. Laina                              female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35.0      1
# Allen, Mr. William Henry                              male  35.0      0
#
#                                                     Parch            Ticket  \
# Name
# ...
